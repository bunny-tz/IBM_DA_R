# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M1_R_Basics/images/IDSNlogo.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1>Web scrape a Global Bike-Sharing Systems Wiki Page</h1>
#
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Lab Overview:
#
# Before getting your hands dirty on the actual data analysis tasks, you first need to obtain some background and context information about well-known bike sharing systems worldwide, such as their location, launch date, rental bike size, and so on.
#
# You can get such information from this Wiki page:
#
# [https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems](https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01)
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-list-bike-sharing-systems.png" width="600" align="center">
# </a>

# %% [markdown]
# First import necessary libraries for the webscraping task.

# %% [markdown]
# In this lab, you need to use the `rvest` library to obtain the bike sharing systems table from the above web page, convert the table into a data frame, and write the data frame to a csv file for future data wrangling and analysis tasks.

# %%
# Check if need to install rvest` library
#require("rvest")

library(rvest)
# Out:
# Warning message:
# "package 'rvest' was built under R version 4.1.3"

# %% [markdown]
# # TASK: Extract bike sharing systems HTML table from a Wiki page and convert it into a data frame

# %% [markdown]
# *TODO:* Get the root HTML node

# %%
url <- "https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems"
# Get the root HTML node by calling the `read_html()` method with URL
root_node <-read_html(url)
root_node
# Out:
# {html_document}
# <html class="client-nojs" lang="en" dir="ltr">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject  ...

# %% [markdown]
# Note that this HTML page at least contains three child `<table>` nodes under the root HTML node. So, you will need to use `html_nodes(root_node, "table")` function to get all its child `<table>` nodes:
#
# ```
# <html>
#   <table>(table1)</table>
#   <table>(table2)</table>
#   <table>(table3)</table>
#   ...
# </html>
# ```

# %% [markdown]
# table_nodes <- html_nodes(root_node, "table")

# %% [markdown]
# You can use a `for` loop to print each table, and then you will see that the actual the bike sharing table is the second element `table_nodes[[2]]`.

# %% [markdown]
# Next, you need to convert this HTML table into a data frame using the `html_table()` function. You may choose to include `fill = TRUE` argument to fill any empty table rows/columns.

# %%
# Convert the bike-sharing system table into a dataframe
table_node <- html_nodes(root_node, "table")
table_node
for (node in table_node){
 print(node)
}
# Out:
# {xml_nodeset (5)}
# [1] <table class="box-Copy_edit plainlinks metadata ambox ambox-style ambox-C ...
# [2] <table class="wikitable sortable" style="text-align:left"><tbody>\n<tr>\n ...
# [3] <table class="nowraplinks mw-collapsible autocollapse navbox-inner" style ...
# [4] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...
# [5] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...
# {html_node}
# <table class="box-Copy_edit plainlinks metadata ambox ambox-style ambox-Copy_edit" role="presentation">
# [1] <tbody><tr>\n<td class="mbox-image"><div class="mbox-image-div"><img alt= ...
# {html_node}
# <table class="wikitable sortable" style="text-align:left">
# [1] <tbody>\n<tr>\n<th>Country</th>\n<th>City</th>\n<th>Name</th>\n<th>System ...
# {html_node}
# <table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# [1] <tbody>\n<tr><th scope="col" class="navbox-title" colspan="2">\n<style da ...
# {html_node}
# <table class="nowraplinks navbox-subgroup" style="border-spacing:0">
# [1] <tbody>\n<tr>\n<th scope="row" class="navbox-group" style="width:1%">East ...
# {html_node}
# <table class="nowraplinks navbox-subgroup" style="border-spacing:0">
# [1] <tbody>\n<tr>\n<th scope="row" class="navbox-group" style="width:1%">Cana ...

# %%
bike_sharing_df<-html_table(table_node[[2]], fill=TRUE)
bike_sharing_df
# Out:
#     Country       City
# 1   Albania       Tirana[5]
# 2   Argentina     Buenos Aires[6][7]
# 3   Argentina     Mendoza[10]
# 4   Argentina     Rosario
# 5   Argentina     San Lorenzo, Santa Fe
# 6   Australia     Melbourne[12]
# 7   Australia     Melbourne[12]
# 8   Australia     Brisbane[14][15]
# 9   Australia     Sydney
# 10  Australia     Sydney
# 11  Australia     Sydney
# 12  Austria       Burgenland
# 13  Austria       Lower Austria[16]
# 14  Austria       Salzburg
# 15  Austria       Vienna
# 16  Austria       Vienna
# 17  Austria       Vorarlberg
# 18  Bangladesh    Dhaka
# 19  Belgium       Different locations[19]
# 20  Belgium       Antwerp
# 21  Belgium       Brussels[24]
# 22  Belgium       Namur[26]
# 23  Brazil        Belo Horizonte[27]
# 24  Brazil        Fortaleza
# 25  Brazil        João Pessoa[28]
# 26  Brazil        (Pedro de) Toledo[29]
# 27  Brazil        Rio de Janeiro[30]
# 28  Brazil        Salvador[31]
# 29  Brazil        São Paulo[32]
# 30  Brazil        Sorocaba[33]
# ... ...           ...
# 491 United States Kansas City, Missouri[306]
# 492 United States Kona District, Hawaii
# 493 United States Lansing, Michigan
# 494 United States Lincoln, Nebraska[308]
# 495 United States Los Angeles
# 496 United States Madison, Wisconsin[309]
# 497 United States Meridian, Colorado
# 498 United States Miami Beach, Florida[310]
# 499 United States Milwaukee[311][312]
# 500 United States Minneapolis–Saint Paul[313][314]
# 501 United States New York City[315][316][317][318][319]
# 502 United States Oklahoma City[320]
# 503 United States Omaha, Nebraska[321]
# 504 United States Philadelphia[322][323]
# 505 United States Phoenix, Arizona
# 506 United States Pittsburgh
# 507 United States Portland, Oregon
# 508 United States Portland, Oregon
# 509 United States Salt Lake City[326]
# 510 United States San Antonio[327]
# 511 United States San Diego[328]
# 512 United States San Francisco Bay Area
# 513 United States San Francisco Bay Area
# 514 United States Santa Monica, California[329]
# 515 United States Savannah, Georgia[330]
# 516 United States Seattle[331]
# 517 United States Spartanburg, South Carolina[332]
# 518 United States St. Paul
# 519 United States Tampa, Florida[333]
# 520 United States Washington metropolitan area[334]
#     Name                        System
# 1   Ecovolis
# 2   Ecobici                     Serttel Brasil[8]
# 3   Metrobici
# 4   Mi Bici Tu Bici[11]
# 5   Biciudad                    Biciudad
# 6   Melbourne Bike Share        PBSC & 8D
# 7   oBike                       4 Gen. oBike
# 8   CityCycle                   3 Gen. Cyclocity
# 9   oBike                       4 Gen. oBike
# 10  Ofo                         4 Gen. Ofo
# 11  Reddy Go                    Reddy Go
# 12  LEIHRADL nextbike           3 Gen. nextbike
# 13  LEIHRADL nextbike           3 Gen. nextbike
# 14  nextbike                    3 Gen. nextbike
# 15  Citybike Wien[17]           3 Gen. Cyclocity
# 16  Viennabike                  2 Gen.
# 17                              3 Gen. nextbike
# 18  JoBike                      JoBike
# 19  dBlue-bike                  Blue-bike
# 20  Velo Antwerp[22]            3 Gen. Clear CC
# 21  Villo!                      3 Gen. Cyclocity
# 22  Libiavelo                   3 Gen. Cyclocity
# 23  Bikebh                      Mobilicidade
# 24  Bicicletar                  Mobilicidade
# 25  SAMBA                       Mobilicidade
# 26  Toopedalando                Toopedalando
# 27  Bike Rio                    tembici
# 28  Bike Salvador               tembici
# 29  Bikesampa                   tembici
# 30  Integrabike                 tembici
# ... ...                         ...
# 491 Kansas City B-cycle         3 Gen. B-Cycle
# 492                             PBSC
# 493 Capital Community Bikeshare A2B Bikeshare
# 494 BikeLNK                     3 Gen. B-Cycle
# 495 Metro Bike Share            3 Gen. B-Cycle
# 496 Madison B-Cycle             3 Gen. B-Cycle
# 497 M-Bike                      Zagster
# 498 Decobike                    SandVault
# 499 Bublr Bikes                 3 Gen. B-Cycle
# 500 Nice Ride                   PBSC & 8D
# 501 Citi Bike                   PBSC & 8D
# 502 Spokies                     Spokies
# 503 Omaha B-Cycle               3 Gen. B-Cycle
# 504 Indego                      3 Gen. B-Cycle (incl. some e-bikes
# 505 Grid Bike Share             3 Gen. CycleHop and Social Bicycles
# 506 Healthy Ride PGH            3 Gen. nextbike
# 507 Biketown
# 508 Yellow Bike Project         1 Gen. WhiteBikes
# 509 SLC Bike Share              3 Gen. B-Cycle
# 510 San Antonio B-Cycle         3 Gen. B-Cycle
# 511 DecoBike                    DecoBike
# 512
# 513 Baywheels                   8D
# 514 Breeze Bike Share           3 Gen. CycleHop and Social Bicycles
# 515 CAT Bike                    3 Gen. B-Cycle
# 516 Pronto Cycle Share          8D
# 517 Spartanburg B-Cycle         3 Gen. B-Cycle
# 518 Yellow Bike Project         1 Gen. w/ BikeCard
# 519 Coast Bike Share            3 Gen. CycleHop and Social Bicycles
# 520 Capital Bikeshare           PBSC & 8D
#     Operator
# 1
# 2   Bike In Baires Consortium.[9]
# 3
# 4
# 5
# 6   Motivate
# 7
# 8   JCDecaux
# 9
# 10
# 11
# 12
# 13
# 14
# 15  JCDecaux Gewista
# 16  Association and city council
# 17
# 18
# 19  Blue-Mobility
# 20  Service2Cities (subsidiary of Clear Channel Belgium)
# 21  JCDecaux
# 22  JCDecaux
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# ... ...
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501 Motivate
# 502
# 503
# 504
# 505
# 506
# 507
# 508 Yellow Bike Project
# 509
# 510
# 511 JCDecaux
# 512
# 513 Motivate
# 514
# 515
# 516 Motivate
# 517
# 518 volunteers and city council
# 519
# 520 Motivate
#     Launched                                Discontinued         Stations
# 1   March 2011                                                   8
# 2   2010                                                         400
# 3   2014                                                         2
# 4   2 December 2015                                              47
# 5   27 November 2016                                             8
# 6   June 2010                               30 November 2019[13] 53
# 7   July 2017                               July 2018            dockless
# 8   September 2010                                               150
# 9   July 2017                               July 2018            dockless
# 10  October 2017                                                 dockless
# 11  July 2017
# 12  2009                                                         40
# 13  2009                                                         295
# 14  2011
# 15  June 2003                                                    121
# 16  April 2002                              November 2002        200
# 17  2009                                                         14
# 18  2018                                                         05
# 19  1 May 2011                                                   70 (2021)[20]
# 20  9 June 2011                                                  305 (2021)
# 21  19 May 2009 (earlier system since 2006)                      346
# 22  21 April 2012                                                24
# 23  2014                                                         40
# 24  15 December 2014                                             80
# 25                                                               3
# 26  2011                                                         6
# 27  2011                                                         60
# 28  2013                                                         23
# 29  2012                                                         241
# 30  2012                                                         15
# ... ...                                     ...                  ...
# 491 2012                                                         30
# 492 2016                                                         3
# 493 2014                                                         8
# 494 2018                                                         19
# 495 7 July 2016                                                  207
# 496 2011                                                         39
# 497 15 March 2010                                                11
# 498 2011                                                         100
# 499 2014                                                         87
# 500 2010                                                         171
# 501 27 May 2013                                                  739
# 502 2012                                                         7
# 503 2011                                                         5
# 504 23 April 2015                                                125
# 505 25 November 2014                                             40
# 506 2015                                                         50
# 507 19 July 2016                                                 100
# 508 1994[324]                               1997[325]
# 509 2013                                                         12
# 510 2011                                                         68
# 511 February 2015                                                180
# 512 2013
# 513 June 2017                                                    550
# 514 13 August 2015                                               80
# 515 24 January 2014                                              2
# 516 13 October 2014                         31 March 2017        50
# 517 2011                                                         5
# 518 1997
# 519 7 December 2014                                              30
# 520 2010                                                         658
#     Bicycles        Daily ridership
# 1   200
# 2   4000            21917
# 3   40
# 4   480
# 5   80
# 6   676
# 7   1250
# 8   2000
# 9   1250
# 10  600
# 11  2000
# 12
# 13  1300
# 14
# 15  1500            2800[18]
# 16  1500
# 17  70
# 18  300
# 19  1790 (2019)[21]
# 20  4200 (2021)     7010[23]
# 21  4115[25]
# 22  200
# 23  400
# 24  800
# 25  20
# 26  60
# 27  300
# 28
# 29  600
# 30  120
# ... ...             ...
# 491 300
# 492 30
# 493 20              Closed[307]
# 494 100
# 495 1700
# 496 350
# 497
# 498 1000
# 499 400+
# 500 1833
# 501 20000           65000
# 502 100
# 503 35
# 504 1400
# 505 500
# 506 500
# 507 1000
# 508 1000
# 509 100
# 510 600
# 511 1800
# 512
# 513 7000
# 514 500
# 515 16
# 516 500
# 517 40
# 518
# 519 300
# 520 5,400

# %% [markdown]
# Summarize the bike sharing system data frame

# %%
# Summarize the dataframe
summary(bike_sharing_df)
# Out:
#    Country              City               Name              System
#  Length:520         Length:520         Length:520         Length:520
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Operator           Launched         Discontinued         Stations
#  Length:520         Length:520         Length:520         Length:520
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Bicycles         Daily ridership
#  Length:520         Length:520
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %% [markdown]
# Export the data frame as a csv file called `raw_bike_sharing_systems.csv`

# %%
# Export the dataframe into a csv file
write.csv(bike_sharing_df, "raw_bike_sharing_systems.csv")

# %% [markdown]
# For more details about webscraping with `rvest`, please refer to the previous webscraping notebook here:
#
# [Webscraping in R](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M4\_Working_With_Data/lab3\_jupyter_webscraping.ipynb)

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-04-05        | 0.1     | Yan        | Initial version created |
# |                   |         |            |                         |
# |                   |         |            |                         |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
